# %%
import pandas as pd

# %% [markdown]
# # 创建DataFrame

# %%
students_data = {"001":{"姓名":"小陈","考试1":85,"考试2":95,"考试3":92},"002":{"姓名":"小李","考试1":91,"考试2":92,"考试3":94},"003":{"姓名":"小王","考试1":86,"考试2":81,"考试3":89},"004":{"姓名":"小张","考试1":79,"考试2":89,"考试3":95},"005":{"姓名":"小赵","考试1":96,"考试2":91,"考试3":91},"006":{"姓名":"小周","考试1":81,"考试2":89,"考试3":92}}
students = pd.DataFrame(students_data).T

# %% [markdown]
# # 增加一列

# %%
students["考试4"] = [72,69,79,83,82,76]
students
# Out:
#      姓名 考试1 考试2 考试3  考试4
# 001  小陈  85  95  92   72
# 002  小李  91  92  94   69
# 003  小王  86  81  89   79
# 004  小张  79  89  95   83
# 005  小赵  96  91  91   82
# 006  小周  81  89  92   76

# %% [markdown]
# # 增加一行

# %%
students.loc["007"] = ["小杨",79,82,81,69]
students
# Out:
#      姓名 考试1 考试2 考试3  考试4
# 001  小陈  85  95  92   72
# 002  小李  91  92  94   69
# 003  小王  86  81  89   79
# 004  小张  79  89  95   83
# 005  小赵  96  91  91   82
# 006  小周  81  89  92   76
# 007  小杨  79  82  81   69

# %% [markdown]
# # 输出删除两行后的结果 axis = 0,操作为索引方向

# %%
students.drop(["006","007"],axis = 0)
# Out:
#      姓名 考试1 考试2 考试3  考试4
# 001  小陈  85  95  92   72
# 002  小李  91  92  94   69
# 003  小王  86  81  89   79
# 004  小张  79  89  95   83
# 005  小赵  96  91  91   82

# %% [markdown]
# # 删除两列

# %%
students.drop(["考试2","考试4"],axis = 1)
# Out:
#      姓名 考试1 考试3
# 001  小陈  85  92
# 002  小李  91  94
# 003  小王  86  89
# 004  小张  79  95
# 005  小赵  96  91
# 006  小周  81  92
# 007  小杨  79  81

# %% [markdown]
# # 将部分列加上一个数

# %%
bonus = pd.Series({"考试1":2,"考试2":3,"考试3":2,"考试4":5})
students = students[["考试1", "考试2", "考试3", "考试4"]] + bonus
students
# Out:
#      考试1  考试2  考试3  考试4
# 001   93  107  100   92
# 002   99  104  102   89
# 003   94   93   97   99
# 004   87  101  103  103
# 005  104  103   99  102
# 006   89  101  100   96

# %% [markdown]
# # 将部分列更新

# %%
students["考试4"] = students["考试4"] + 10
students
# Out:
#      考试1  考试2  考试3  考试4
# 001   93  107  100  112
# 002   99  104  102  109
# 003   94   93   97  119
# 004   87  101  103  123
# 005  104  103   99  122
# 006   89  101  100  116
